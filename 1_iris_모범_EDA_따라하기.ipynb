# %% [markdown]
# <a href="https://colab.research.google.com/github/temple17/dacon_practice/blob/main/1_iris_%EB%AA%A8%EB%B2%94_EDA_%EB%94%B0%EB%9D%BC%ED%95%98%EA%B8%B0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# 작업이 진행되는 곳을 변경

# %cd "/content/drive/MyDrive/dacon/1_iris"
# Out:
# /content/drive/MyDrive/dacon/1_iris

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
iris = pd.read_csv('iris_train.csv')

# %%
iris.head(10)
# Out:
#    id     species  ...  sepal width (cm)  petal width (cm)
# 0   0      setosa  ...               2.9               0.2
# 1   1  versicolor  ...               3.2               1.5
# 2   2   virginica  ...               2.8               1.8
# 3   3   virginica  ...               3.6               2.5
# 4   4      setosa  ...               3.0               0.2
# 5   5   virginica  ...               3.0               2.2
# 6   6      setosa  ...               3.0               0.1
# 7   7  versicolor  ...               3.0               1.7
# 8   8  versicolor  ...               2.8               1.4
# 9   9  versicolor  ...               3.0               1.4
#
# [10 rows x 6 columns]

# %%
sepal_length = iris["sepal length (cm)"] # 꽃받침 길이
petal_length = iris["petal length (cm)"] # 꽃잎의 길이

sum_of_sepal_length = sum(sepal_length) # 꽃받침 길이의 합
sum_of_petal_length = sum(petal_length) # 꽃잎 길이의 합

# 꽃받침 길이의 합/ 총 꽃받침 갯수
mean_of_sepal_length = sum_of_sepal_length / len(sepal_length) 

# 꽃잎 길이의 합/ 총 꽃잎 갯수
mean_of_petal_length = sum_of_petal_length / len(petal_length)

print("모든 꽃받침의 평균 길이:", round(mean_of_sepal_length,3))
print("모든 꽃잎의 평균 길이:", round(mean_of_petal_length,3))
# Out:
# 모든 꽃받침의 평균 길이: 6.044
# 모든 꽃잎의 평균 길이: 4.259

# %%
# %matplotlib inline

# %%
# 붓꽃 종류별 평균 길이

virginica = iris[iris["species"] == "virginica"] # 전체 붓꽃 데이터에서 virginica만 추출
setosa = iris[iris["species"] == "setosa"] # 전체 붓꽃 데이터에서 setosa만 추출
versicolor = iris[iris["species"] == "versicolor"] # 전체 붓꽃 데이터에서 versicolor만 추출

# %%
plt.style.use('ggplot') # R의 ggplot 스타일로 출력
plt.figure(figsize= (7,7))

amount_of_virginica = len(virginica)
amount_of_setosa = len(setosa)
amount_of_versicolor = len(versicolor)

species_count = [amount_of_virginica, amount_of_setosa, amount_of_versicolor]
colors = sns.color_palette('hls', len(species_count))
plt.bar(['virginica', 'setosa', 'versicolor'], species_count, color = colors)
plt.tick_params(axis = 'x', labelsize = 18)
plt.tick_params(axis = 'y', labelsize= 18)
plt.title('iris species count', fontsize = 25)
# Out:
# Text(0.5, 1.0, 'iris species count')

# %%
print("virginica 꽃받침 길이 평균:", round(np.mean(virginica['sepal length (cm)']),3))
print("virginica 꽃잎 길이 평균:", round(np.mean(virginica['petal length (cm)']),3))
mean_of_virginica_sepal_length = round(np.mean(virginica['sepal length (cm)']),3)
mean_of_virginica_petal_length = round(np.mean(virginica['petal length (cm)']),3)


print('\n')

print("setosa 꽃잎 길이 평균:", round(np.mean(setosa['sepal length (cm)']),3))
print("setosa 꽃잎 길이 평균:", round(np.mean(setosa['petal length (cm)']),3))
mean_of_setosa_sepal_length = round(np.mean(setosa['sepal length (cm)']),3)
mean_of_setosa_petal_length = round(np.mean(setosa['petal length (cm)']),3)

print('\n')

print("versicolor 꽃잎 길이 평균:", round(np.mean(versicolor['sepal length (cm)']),3))
print("versicolor 꽃잎 길이 평균:", round(np.mean(versicolor['petal length (cm)']),3))
mean_of_versicolor_sepal_length = round(np.mean(versicolor['sepal length (cm)']),3)
mean_of_versicolor_petal_length = round(np.mean(versicolor['petal length (cm)']),3)
# Out:
# virginica 꽃받침 길이 평균: 6.583
# virginica 꽃잎 길이 평균: 5.603
#
#
# setosa 꽃잎 길이 평균: 4.913
# setosa 꽃잎 길이 평균: 1.42
#
#
# versicolor 꽃잎 길이 평균: 6.07
# versicolor 꽃잎 길이 평균: 4.333

# %%
print("전체 꽃받침 너비 평균:", round(np.mean(iris['sepal width (cm)']),3))
mean_of_sepal_width = round(np.mean(iris['sepal width (cm)']),3)

print("전체 꽃잎 너비 평균:", round(np.mean(iris['petal width (cm)']),3))
mean_of_petal_width = round(np.mean(iris['petal width (cm)']),3)
# Out:
# 전체 꽃받침 너비 평균: 2.959
# 전체 꽃잎 너비 평균: 1.384

# %%
print("virginica 꽃받침 너비 평균:", round(np.mean(virginica['sepal width (cm)']),3))
print("virginica 꽃잎 너비 평균:", round(np.mean(virginica['petal width (cm)']),3))
mean_of_virginica_sepal_width = round(np.mean(virginica['sepal width (cm)']),3)
mean_of_virginica_petal_width = round(np.mean(virginica['petal width (cm)']),3)

print('\n')

print("setosa 꽃잎 너비 평균:", round(np.mean(setosa['sepal width (cm)']),3))
print("setosa 꽃잎 너비 평균:", round(np.mean(setosa['petal width (cm)']),3))
mean_of_setosa_sepal_width = round(np.mean(setosa['sepal width (cm)']),3)
mean_of_setosa_petal_width = round(np.mean(setosa['petal width (cm)']),3)

print('\n')

print("versicolor 꽃잎 너비 평균:", round(np.mean(versicolor['sepal width (cm)']),3))
print("versicolor 꽃잎 너비 평균:", round(np.mean(versicolor['petal width (cm)']),3))
mean_of_versicolor_sepal_width = round(np.mean(versicolor['sepal width (cm)']),3)
mean_of_versicolor_petal_width = round(np.mean(versicolor['petal width (cm)']),3)
# Out:
# virginica 꽃받침 너비 평균: 2.933
# virginica 꽃잎 너비 평균: 2.007
#
#
# setosa 꽃잎 너비 평균: 3.347
# setosa 꽃잎 너비 평균: 0.2
#
#
# versicolor 꽃잎 너비 평균: 2.79
# versicolor 꽃잎 너비 평균: 1.353

# %%
# 너비와 길이의 비율

sepal_length_over_width = mean_of_sepal_length/mean_of_sepal_width
petal_length_over_width = mean_of_petal_length/mean_of_petal_width

print("꽃받침의 길이에 대한 너비의 비율:", sepal_length_over_width)
print("꽃잎의 길이에 대한 너비의 비율:", petal_length_over_width)
# Out:
# 꽃받침의 길이에 대한 너비의 비율: 2.042581953362623
# 꽃잎의 길이에 대한 너비의 비율: 3.077071290944124

# %%
# 비율을 전체 길이에 나누어 너비를 구하고, 각 데이터마다 에러값 확인해보기

sepal_width_pred = sepal_length/sepal_length_over_width

sepal_width = iris['sepal width (cm)']


error = [abs(true - pred) for true, pred in zip(sepal_width, sepal_width_pred)]

plt.figure(figsize=(20,10))

plt.bar(x = range(len(error)), height = error)

plt.title('Error between real and predicted speal length (cm)', fontsize = 19)

arrowprops = {
    'facecolor':'black',
    'edgecolor':'b',
    'headwidth': 15,
    'shrink':0
}

plt.annotate('error is too big', ha = 'center', va = 'bottom', xytext = (35, max(error)),
             xy = (21, max(error)),
             fontsize = 15,
             arrowprops = arrowprops)

plt.annotate('', ha = 'center', va = 'bottom', xytext = (39, max(error)),
             xy = (50, error[50]),
             fontsize = 15,
             arrowprops = arrowprops)
# Out:
# Text(39, 1.2562872270019856, '')

# %%
# 2차원 그래프
# 길이와 너비의 상관관계

plt.figure(figsize = (20,8))
plt.subplot(1,2,1)

plt.scatter(sepal_length, sepal_width, color = 'b')
plt.xlabel('sepal_length', fontsize = 15)
plt.ylabel('sepal_width', fontsize = 15)
plt.title('Sepal', fontsize = 30)

plt.subplot(1,2,2)

petal_width = iris['petal width (cm)']

plt.scatter(petal_length, petal_width, color = 'r')
plt.xlabel('petal_length', fontsize = 15)
plt.ylabel('petal_width', fontsize = 15)
plt.title('Petal', fontsize = 30)
# Out:
# Text(0.5, 1.0, 'Petal')

# %%
# 종류별로 상관관계 살펴보기

plt.figure(figsize = (20,8))
plt.subplot(1,2,1)
sns.scatterplot(x = iris['sepal length (cm)'],
                y = iris['sepal width (cm)'],
                hue = iris['species'])

plt.annotate('', ha = 'center', va = 'bottom', xytext = (4.1,3.0),
             xy = (5.7,4),
             fontsize = 15,
             arrowprops = {
                 'facecolor': 'r',
                 'edgecolor': 'black',
                 'headwidth': 15,
                 'shrink':1
             })

plt.annotate('', ha = 'center', va = 'bottom', xytext = (4.7,2.0),
             xy = (6.5,3.1),
             fontsize = 15,
             arrowprops = {
                 'facecolor': 'b',
                 'edgecolor': 'black',
                 'headwidth': 15,
                 'shrink':0
             })

plt.annotate('', ha = 'center', va = 'bottom', xytext = (6.3,2.5),
             xy = (7.5,3.25),
             fontsize = 15,
             arrowprops = {
                 'facecolor': 'indigo',
                 'edgecolor': 'black',
                 'headwidth': 15,
                 'shrink':1
             })
plt.xlabel('sepal_length', fontsize = 15)
plt.ylabel('sepal_width', fontsize = 15)
plt.title('Sepal', fontsize = 30)

plt.subplot(1,2,2)
sns.scatterplot(x = iris['petal length (cm)'],
                y = iris['petal width (cm)'],
                hue = iris['species'])

plt.xlabel('petal_length', fontsize =15)
plt.ylabel('petal_width', fontsize = 15)
plt.title('Petal', fontsize = 30)

plt.gca().add_patch(plt.Circle((1.5,0.25),.3, color = 'r', fill = False))
plt.gca().add_patch(plt.Circle((4,1.25),.7, color = 'b', fill = False))
plt.gca().add_patch(plt.Circle((5.8,2),1, color = 'indigo', fill = False))

# %%
# 3차원 그래프

fig = plt.figure(figsize = (20,13))
fig.suptitle('3D plots: relation with width and length', fontsize = 25)

ax = fig.add_subplot(1,2,1, projection = '3d')

ax.view_init(20,110)
ax.set_title('Sepal width with lengthes', fontsize = 19)
ax.scatter(iris['sepal length (cm)'], iris['petal length (cm)'], iris['sepal width (cm)'], s=100)
ax.set_xlabel('sepal lengh (cm)', fontsize = 14)
ax.set_ylabel('petal length (cm)', fontsize = 14)
ax.set_zlabel('sepal width (cm)', fontsize = 14)

ax_2 = fig.add_subplot(1,2,2, projection = '3d')

ax_2.view_init(20,110)
ax_2.set_title('petal width with lengthes', fontsize = 19)
ax_2.scatter(iris['sepal length (cm)'], iris['petal length (cm)'], iris['petal width (cm)'], s=100, color = 'b')
ax_2.set_xlabel('sepal length (cm)', fontsize = 14)
ax_2.set_ylabel('petal length (cm)', fontsize = 14)
ax_2.set_zlabel('peatl width (cm)', fontsize = 14)

fig.tight_layout()

# %%
# 종류별로 나눠서 3d 시각화하기

fig = plt.figure(figsize = (20,13))
fig.suptitle('3D plots: relation with width and length', fontsize = 25)

ax = fig.add_subplot(1,2,1, projection = '3d')

ax.view_init(20,110)
ax.set_title('Sepal width with lengthes', fontsize = 19)
ax.scatter(virginica['sepal length (cm)'], virginica['petal length (cm)'], virginica['sepal width (cm)'], s=100, color = 'r', marker = 'x', label = 'virginica')
ax.scatter(setosa['sepal length (cm)'], setosa['petal length (cm)'], setosa['sepal width (cm)'], s=100, color = 'b', marker = '^', label = 'setosa')
ax.scatter(versicolor['sepal length (cm)'], versicolor['petal length (cm)'], versicolor['sepal width (cm)'], s=100, color = 'indigo', marker = 'o', label = 'versicolor')

ax.set_xlabel('sepal lengh (cm)', fontsize = 14)
ax.set_ylabel('petal length (cm)', fontsize = 14)
ax.set_zlabel('sepal width (cm)', fontsize = 14)

ax_2 = fig.add_subplot(1,2,2, projection = '3d')

ax_2.view_init(20,110)
ax_2.set_title('petal width with lengthes', fontsize = 19)
ax_2.scatter(virginica['sepal length (cm)'], virginica['petal length (cm)'], virginica['petal width (cm)'], s=100, color = 'r', marker = 'x', label = 'virginica')
ax_2.scatter(setosa['sepal length (cm)'], setosa['petal length (cm)'], setosa['petal width (cm)'], s=100, color = 'b', marker = '^', label = 'setosa')
ax_2.scatter(versicolor['sepal length (cm)'], versicolor['petal length (cm)'], versicolor['petal width (cm)'], s=100, color = 'indigo', marker = 'o', label = 'versicolor')
ax_2.set_xlabel('sepal length (cm)', fontsize = 14)
ax_2.set_ylabel('petal length (cm)', fontsize = 14)
ax_2.set_zlabel('peatl width (cm)', fontsize = 14)

fig.tight_layout()

# %%
# plotly를 이용한 시각화

import plotly.express as px

fig = px.scatter_3d(iris, x = 'sepal length (cm)', y = 'petal length (cm)', z = 'sepal width (cm)', color = 'species')
fig.update_layout(title = '꽃받침 너비', autosize = False, width = 1000, height = 800)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="a995c1c7-ac77-49ee-8a84-d58462240506" class="plotly-graph-div" style="height:800px; width:1000px;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("a995c1c7-ac77-49ee-8a84-d58462240506")) {
#                     Plotly.newPlot(
#                         'a995c1c7-ac77-49ee-8a84-d58462240506',
#                         [{"hoverlabel": {"namelength": 0}, "hovertemplate": "species=setosa<br>sepal length (cm)=%{x}<br>petal length (cm)=%{y}<br>sepal width (cm)=%{z}", "legendgroup": "species=setosa", "marker": {"color": "#636efa", "symbol": "circle"}, "mode": "markers", "name": "species=setosa", "scene": "scene", "showlegend": true, "type": "scatter3d", "x": [4.4, 4.9, 4.3, 4.6, 5.8, 5.1, 5.4, 5.0, 4.9, 4.7, 4.6, 5.0, 5.4, 4.8, 4.8], "y": [1.4, 1.4, 1.1, 1.5, 1.2, 1.4, 1.7, 1.5, 1.5, 1.3, 1.4, 1.4, 1.5, 1.4, 1.6], "z": [2.9, 3.0, 3.0, 3.1, 4.0, 3.5, 3.9, 3.4, 3.1, 3.2, 3.4, 3.6, 3.7, 3.0, 3.4]}, {"hoverlabel": {"namelength": 0}, "hovertemplate": "species=versicolor<br>sepal length (cm)=%{x}<br>petal length (cm)=%{y}<br>sepal width (cm)=%{z}", "legendgroup": "species=versicolor", "marker": {"color": "#EF553B", "symbol": "circle"}, "mode": "markers", "name": "species=versicolor", "scene": "scene", "showlegend": true, "type": "scatter3d", "x": [6.4, 6.7, 6.8, 6.6, 5.0, 6.3, 6.7, 5.5, 5.2, 6.4, 5.6, 5.8, 5.9, 6.0, 6.3, 6.1, 6.1, 5.7, 6.6, 6.1, 6.0, 5.9, 7.0, 5.6, 5.7, 6.5, 5.6, 6.2, 4.9, 6.9], "y": [4.5, 5.0, 4.8, 4.4, 3.5, 4.7, 4.4, 4.0, 3.9, 4.3, 3.9, 4.1, 4.2, 4.5, 4.9, 4.0, 4.7, 4.5, 4.6, 4.7, 4.0, 4.8, 4.7, 4.5, 3.5, 4.6, 3.6, 4.5, 3.3, 4.9], "z": [3.2, 3.0, 2.8, 3.0, 2.0, 3.3, 3.1, 2.3, 2.7, 2.9, 2.5, 2.7, 3.0, 2.9, 2.5, 2.8, 2.8, 2.8, 2.9, 2.9, 2.2, 3.2, 3.2, 3.0, 2.6, 2.8, 2.9, 2.2, 2.4, 3.1]}, {"hoverlabel": {"namelength": 0}, "hovertemplate": "species=virginica<br>sepal length (cm)=%{x}<br>petal length (cm)=%{y}<br>sepal width (cm)=%{z}", "legendgroup": "species=virginica", "marker": {"color": "#00cc96", "symbol": "circle"}, "mode": "markers", "name": "species=virginica", "scene": "scene", "showlegend": true, "type": "scatter3d", "x": [6.2, 7.2, 6.5, 6.3, 7.6, 7.7, 7.1, 6.0, 6.8, 7.3, 6.9, 4.9, 6.4, 7.7, 6.3, 6.7, 6.5, 7.7, 7.2, 6.4, 6.3, 6.7, 6.5, 6.4, 5.6, 5.8, 7.2, 5.8, 6.1, 5.7], "y": [4.8, 6.1, 5.8, 4.9, 6.6, 6.9, 5.9, 5.0, 5.5, 6.3, 5.7, 4.5, 5.6, 6.7, 6.0, 5.8, 5.1, 6.7, 6.0, 5.3, 5.6, 5.7, 5.5, 5.3, 4.9, 5.1, 5.8, 5.1, 4.9, 5.0], "z": [2.8, 3.6, 3.0, 2.7, 3.0, 2.6, 3.0, 2.2, 3.0, 2.9, 3.2, 2.5, 2.8, 3.8, 3.3, 2.5, 3.2, 2.8, 3.2, 2.7, 2.9, 3.3, 3.0, 3.2, 2.8, 2.8, 3.0, 2.7, 3.0, 2.5]}],
#                         {"autosize": false, "height": 800, "legend": {"tracegroupgap": 0}, "margin": {"t": 60}, "scene": {"domain": {"x": [0.0, 1.0], "y": [0.0, 1.0]}, "xaxis": {"title": {"text": "sepal length (cm)"}}, "yaxis": {"title": {"text": "petal length (cm)"}}, "zaxis": {"title": {"text": "sepal width (cm)"}}}, "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2d"}], "histogram2dcontour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2dcontour"}], "mesh3d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "mesh3d"}], "parcoords": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "parcoords"}], "pie": [{"automargin": true, "type": "pie"}], "scatter": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter"}], "scatter3d": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter3d"}], "scattercarpet": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattercarpet"}], "scattergeo": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergeo"}], "scattergl": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergl"}], "scattermapbox": [{"marker": {"colorbar": {"outlinewidth": 0, ...

# %%
fig = px.scatter_3d(iris, x = 'sepal length (cm)', y = 'petal length (cm)', z = 'petal width (cm)', color = 'species')
fig.update_layout(title = '꽃잎 너비', autosize = False, width = 1000, height = 800)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="5fd06def-80a0-4237-9893-5797b8ff18f1" class="plotly-graph-div" style="height:800px; width:1000px;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("5fd06def-80a0-4237-9893-5797b8ff18f1")) {
#                     Plotly.newPlot(
#                         '5fd06def-80a0-4237-9893-5797b8ff18f1',
#                         [{"hoverlabel": {"namelength": 0}, "hovertemplate": "species=setosa<br>sepal length (cm)=%{x}<br>petal length (cm)=%{y}<br>petal width (cm)=%{z}", "legendgroup": "species=setosa", "marker": {"color": "#636efa", "symbol": "circle"}, "mode": "markers", "name": "species=setosa", "scene": "scene", "showlegend": true, "type": "scatter3d", "x": [4.4, 4.9, 4.3, 4.6, 5.8, 5.1, 5.4, 5.0, 4.9, 4.7, 4.6, 5.0, 5.4, 4.8, 4.8], "y": [1.4, 1.4, 1.1, 1.5, 1.2, 1.4, 1.7, 1.5, 1.5, 1.3, 1.4, 1.4, 1.5, 1.4, 1.6], "z": [0.2, 0.2, 0.1, 0.2, 0.2, 0.2, 0.4, 0.2, 0.1, 0.2, 0.3, 0.2, 0.2, 0.1, 0.2]}, {"hoverlabel": {"namelength": 0}, "hovertemplate": "species=versicolor<br>sepal length (cm)=%{x}<br>petal length (cm)=%{y}<br>petal width (cm)=%{z}", "legendgroup": "species=versicolor", "marker": {"color": "#EF553B", "symbol": "circle"}, "mode": "markers", "name": "species=versicolor", "scene": "scene", "showlegend": true, "type": "scatter3d", "x": [6.4, 6.7, 6.8, 6.6, 5.0, 6.3, 6.7, 5.5, 5.2, 6.4, 5.6, 5.8, 5.9, 6.0, 6.3, 6.1, 6.1, 5.7, 6.6, 6.1, 6.0, 5.9, 7.0, 5.6, 5.7, 6.5, 5.6, 6.2, 4.9, 6.9], "y": [4.5, 5.0, 4.8, 4.4, 3.5, 4.7, 4.4, 4.0, 3.9, 4.3, 3.9, 4.1, 4.2, 4.5, 4.9, 4.0, 4.7, 4.5, 4.6, 4.7, 4.0, 4.8, 4.7, 4.5, 3.5, 4.6, 3.6, 4.5, 3.3, 4.9], "z": [1.5, 1.7, 1.4, 1.4, 1.0, 1.6, 1.4, 1.3, 1.4, 1.3, 1.1, 1.0, 1.5, 1.5, 1.5, 1.3, 1.2, 1.3, 1.3, 1.4, 1.0, 1.8, 1.4, 1.5, 1.0, 1.5, 1.3, 1.5, 1.0, 1.5]}, {"hoverlabel": {"namelength": 0}, "hovertemplate": "species=virginica<br>sepal length (cm)=%{x}<br>petal length (cm)=%{y}<br>petal width (cm)=%{z}", "legendgroup": "species=virginica", "marker": {"color": "#00cc96", "symbol": "circle"}, "mode": "markers", "name": "species=virginica", "scene": "scene", "showlegend": true, "type": "scatter3d", "x": [6.2, 7.2, 6.5, 6.3, 7.6, 7.7, 7.1, 6.0, 6.8, 7.3, 6.9, 4.9, 6.4, 7.7, 6.3, 6.7, 6.5, 7.7, 7.2, 6.4, 6.3, 6.7, 6.5, 6.4, 5.6, 5.8, 7.2, 5.8, 6.1, 5.7], "y": [4.8, 6.1, 5.8, 4.9, 6.6, 6.9, 5.9, 5.0, 5.5, 6.3, 5.7, 4.5, 5.6, 6.7, 6.0, 5.8, 5.1, 6.7, 6.0, 5.3, 5.6, 5.7, 5.5, 5.3, 4.9, 5.1, 5.8, 5.1, 4.9, 5.0], "z": [1.8, 2.5, 2.2, 1.8, 2.1, 2.3, 2.1, 1.5, 2.1, 1.8, 2.3, 1.7, 2.1, 2.2, 2.5, 1.8, 2.0, 2.0, 1.8, 1.9, 1.8, 2.1, 1.8, 2.3, 2.0, 2.4, 1.6, 1.9, 1.8, 2.0]}],
#                         {"autosize": false, "height": 800, "legend": {"tracegroupgap": 0}, "margin": {"t": 60}, "scene": {"domain": {"x": [0.0, 1.0], "y": [0.0, 1.0]}, "xaxis": {"title": {"text": "sepal length (cm)"}}, "yaxis": {"title": {"text": "petal length (cm)"}}, "zaxis": {"title": {"text": "petal width (cm)"}}}, "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2d"}], "histogram2dcontour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2dcontour"}], "mesh3d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "mesh3d"}], "parcoords": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "parcoords"}], "pie": [{"automargin": true, "type": "pie"}], "scatter": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter"}], "scatter3d": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter3d"}], "scattercarpet": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattercarpet"}], "scattergeo": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergeo"}], "scattergl": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergl"}], "scattermapbox": [{"marker": {"colorbar": {"outlinewidth": 0, ...
